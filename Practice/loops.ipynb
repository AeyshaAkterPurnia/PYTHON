# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 10
if a >15:
  print("'a' is greater than 15")
elif a <15:
  print("'a' is less then 15")
else:
  print("'a' is zero")
# Out:
# 'a' is less then 15

# %%
age = 20
if age >= 18:
  print("You are an adult")
  print("You can vote")
  print("You have full legal rights")
# Out:
# You are an adult
# You can vote
# You have full legal rights

# %%
is_logged_in = True
if is_logged_in:
  print("Welcome back!")
# Out:
# Welcome back!

# %%
a = 10
b = 20
if a >b:
  print("'a' is greater than b")
elif a <b:
  print("'a' is less then b")
elif a == b:
  print("'a' is equal tp b")
# Out:
# 'a' is less then b

# %%
score = 75

if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
# Out:
# Grade: C

# %%
number = 7

if number % 2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# The number is odd

# %%
username = "Emil"

if len(username) > 0:
  print(f"Welcome, {username}!")
else:
  print("Error: Username cannot be empty")
# Out:
# Welcome, Emil!

# %%
a = 5
b = 7
print("A") if a>b else print("B")
# Out:
# B

# %%
a = 10
b = 20
