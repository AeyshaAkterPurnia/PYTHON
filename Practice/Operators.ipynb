# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10+5)
a = 10+20
b = a+20
c = a+b
print(c)
print(a*b)
print(c-a)
print(c/b)
# Out:
# 15
# 80
# 1500
# 50
# 1.6

# %%
print(c//b)
# Out:
# 1

# %%
a = [2,4,6,8,10]
count = len(a)
if count>3:
  print(f"List has {count} elements")

if(count:= len(a))>3:
  print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %%
a = 3
b = 4

print(a == b)
print(a != b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a= 4
print(1<a<5)
print(1<a and a<5)
# Out:
# True
# True

# %%
fruits = ["apple", "banana", "cherry"]

print("pineapple" not in fruits)
# Out:
# True

# %%
text = "Hello World"

print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# False
# True

# %%
print((6 + 3) - (6 + 3))
# Out:
# 0
