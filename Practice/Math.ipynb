# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = min(5, 10, 25)
y = max(5, 10, 25)

print(x)
print(y)
# Out:
# 5
# 25

# %%
x = abs(-7.25)
print(x)
# Out:
# 7.25

# %%
x = pow(4, 3)
print(x)
# Out:
# 64

# %%
import math
x = math.sqrt(64)
print(x)
# Out:
# 8.0

# %%
import math
x = math.ceil(1.4)
y = math.floor(1.4)
print(x)
print(y)
# Out:
# 2
# 1

# %%
import math
x = math.pi
print(x)
# Out:
# 3.141592653589793

# %%
a = input()
b = input()
print(a+b)
# Out:
# 12
# 21
# 1221

# %%
a = int(input("Enter First Value:"))
b = int(input("Enter Second Value:"))
print("Summation is:", a+b)
# Out:
# Enter First Value:12
# Enter Second Value:21
# Summation is: 33

# %%
a = 2j
b = 1+1j
print(a+b)
# Out:
# (1+3j)

# %%
fname = input("Enter your first name:")
lname = input("Enter your last name:")
print("Your full name is", fname +" "+lname)
# Out:
# Enter your first name:Aeysha
# Enter your last name:Purnia
# Your full name is Aeysha Purnia

# %%
a = int(input())
b = float(input())
print(a/b)
print(a*b)
print(a+b)
print(a-b)
# Out:
# 10
# 2
# 5.0
# 20.0
# 12.0

# %%
import random
print(random.randrange(0,40))
# Out:
# 2

# %%
a = int(input("Enter any number: "))
b = int(input("Enter any number again:"))
if a<b:
  print(b, "is greater than",a)
elif a>b:
  print(a, "is greater than",b)
else:
  print(a, "is equal to",b)
# Out:
# Enter any number: 2
# Enter any number again:8
# 8 is greater than 2

# %%
a = 3
b = 2
print(a ** b) # ** means power
print(pow(a,b)) #same thing
# Out:
# 9
# 9
