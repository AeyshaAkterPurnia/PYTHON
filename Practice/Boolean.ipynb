# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10>9)
print(5==5)
print(3<1)

a = 55
b = 23

if b>a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# True
# True
# False
# b is not greater than a

# %%
print(bool("Purnia"))
print(bool(2))
# Out:
# True
# True

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!
