# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name_set = {"purnia", "Farjana", "Aeysha"}
print(name_set)
# Out:
# {'Aeysha', 'Farjana', 'purnia'}

# %%
name_set = {"purnia", "Farjana", "Aeysha", "Purnia", "purnia", "aeysha"}
print(name_set)
# Out:
# {'Aeysha', 'aeysha', 'Purnia', 'Farjana', 'purnia'}

# %%
name_set = {"purnia", "Farjana", "Aeysha", True, 1, 2,0}
print(name_set)
# Out:
# {0, True, 2, 'Aeysha', 'Farjana', 'purnia'}

# %%
name_set = {"purnia", "Farjana", "Aeysha", True, False,0}
print(name_set)
# Out:
# {False, True, 'Aeysha', 'Farjana', 'purnia'}

# %%
name_set = {"purnia", "Farjana", "Aeysha", True, 1, 2,0}
print(len(name_set))
# Out:
# 6

# %%
name_set = {"purnia", "Farjana", "Aeysha", True, 22, 0}
print(name_set)
# Out:
# {0, True, 'Aeysha', 22, 'Farjana', 'purnia'}

# %%
name_set = {"purnia", "Farjana", "Aeysha"}
print(type(name_set))
# Out:
# <class 'set'>

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya"}
fruits.update(more_fruits)
print(fruits)
# Out:
# {'Pineapple', 'Mango', 'Papaya', 'Apple', 'Banana', 'watermilon', 'Goava'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = ["watermilon", "Mango", "Papaya"]
fruits.update(more_fruits)
print(fruits)
# Out:
# {'Mango', 'Banana', 'Pineapple', 'Papaya', 'Apple', 'watermilon', 'Goava'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
fruits.remove("Goava")
print(fruits)
# Out:
# {'Pineapple', 'Banana', 'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
fruits.discard("Goava")
print(fruits)
# Out:
# {'Pineapple', 'Banana', 'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}

x = fruits.pop()
print(x)
print(fruits)
# Out:
# Pineapple
# {'Banana', 'Goava', 'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
fruits.clear()
print(fruits)
# Out:
# set()

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
del fruits
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3577386639.py in <cell line: 0>()
#       1 fruits = {"Apple", "Pineapple", "Goava", "Banana"}
#       2 del fruits
# ----> 3 print(fruits)
#
# NameError: name 'fruits' is not defined

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
for x in fruits:
  print(x)
# Out:
# Pineapple
# Banana
# Goava
# Apple

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
num = {1,2,3,4,5}
join = fruits.union(num)
print(join)
# Out:
# {1, 2, 3, 4, 5, 'Banana', 'Pineapple', 'Apple', 'Goava'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
num = {1,2,3,4,5}
join = fruits | num
print(join)
# Out:
# {1, 2, 3, 4, 5, 'Banana', 'Pineapple', 'Apple', 'Goava'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
num = {1,2,3,4,5}
name = {"Aeysha", "Purnia"}
boolean = {True, False}
join = fruits.union(num, name,boolean)
print(join)
# Out:
# {False, 1, 2, 3, 4, 'Apple', 5, 'Aeysha', 'Purnia', 'Banana', 'Goava', 'Pineapple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
num = {1,2,3,4,5}
name = {"Aeysha", "Purnia"}
boolean = {True, False}
join = fruits | num | name | boolean
print(join)
# Out:
# {False, 1, 2, 3, 4, 'Apple', 5, 'Aeysha', 'Purnia', 'Banana', 'Goava', 'Pineapple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
num = {1,2,3,4,5}
fruits.update(num)
print(fruits)
# Out:
# {1, 2, 3, 4, 'Apple', 5, 'Banana', 'Goava', 'Pineapple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya", "Apple"}
set1 = fruits.intersection(more_fruits)
print(set1)
# Out:
# {'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya", "Apple"}

set2 = fruits & more_fruits
print(set2)
# Out:
# {'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya", "Apple", "Goava"}

set3 = fruits.intersection_update(more_fruits)
print(set3)
# Out:
# None

# %%
group1 = {"Apple", "Cherry", 1, 0, "Banana"}
group2 = {False,"watermilon", 2, "Papaya",1, "Apple", "Goava", True}
group4 = group1.intersection(group2)
print(group4)
# Out:
# {0, 1, 'Apple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya", "Apple", "Goava"}
set4 = fruits.difference(more_fruits)
print(set4)
# Out:
# {'Banana', 'Pineapple'}

# %%
fruits = {"Apple", "Pineapple", "Goava", "Banana"}
more_fruits = {"watermilon", "Mango", "Papaya", "Apple", "Goava"}
set5 = fruits - more_fruits
print(set5)
# Out:
# {'Banana', 'Pineapple'}
