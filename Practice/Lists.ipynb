# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
result_list =["A+", "A", "B+", "B", "C+", "C", "D+", "D"]
print(result_list)
print(len(result_list))
print(type(result_list))
print(result_list[0])
print(result_list[1])
print(result_list[5])
print(result_list[-2])
print(result_list[2:5])
print(result_list[:5])
print(result_list[2:])
print(result_list[-4:-1])
# Out:
# ['A+', 'A', 'B+', 'B', 'C+', 'C', 'D+', 'D']
# 8
# <class 'list'>
# A+
# A
# C
# D+
# ['B+', 'B', 'C+']
# ['A+', 'A', 'B+', 'B', 'C+']
# ['B+', 'B', 'C+', 'C', 'D+', 'D']
# ['C+', 'C', 'D+']

# %%
result_list =["A+", "A", "B+", "B", "C+", "C", "D+", "D"]
if "C+" in result_list:
  print("Yes, 'apple' is in the result list")
else:
  print("No")
# Out:
# Yes, 'apple' is in the result list
