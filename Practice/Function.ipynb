# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func():
  print("Hello!, Function")
func()
func()
# Out:
# Hello!, Function
# Hello!, Function

# %%
samp1 = 77
cal1 = (samp1 - 32) * 5 / 9
print(cal1)

samp2 = 90
cal2 = (samp2 - 32) * 5 / 9
print(cal2)

cal3 = cal2 - cal1
print(cal3)
# Out:
# 25.0
# 32.22222222222222
# 7.222222222222221

# %%
def farenheit_to_cal(farenheit):
  return (farenheit - 32) * 5 / 9
print(farenheit_to_cal(90))
print(farenheit_to_cal(20))
print(farenheit_to_cal(46))
# Out:
# 32.22222222222222
# -6.666666666666667
# 7.777777777777778

# %%
def get_greeting():
  return "Hello!!, From a function"

message = get_greeting()
print(message)
print(get_greeting())
# Out:
# Hello!!, From a function
# Hello!!, From a function

# %%
def get_greeting():
  pass

# %%
def get_greeting(fname):
  print(fname + "Purnia")

get_greeting("Aeysha ")
get_greeting("Akter ")
# Out:
# Aeysha Purnia
# Akter Purnia

# %%
def get_greeting(fname):
  print(fname , "Purnia")

get_greeting("Aeysha ")
# Out:
# Aeysha  Purnia

# %%
def get_greeting(fname, lname):
  print(fname + " Akter "+ lname)

get_greeting("Aeysha", "Purnia")
# Out:
# Aeysha Akter Purnia

# %%
def get_greeting(fname, lname):
  print(fname + " Akter "+ lname)

get_greeting("Aeysha")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2300808540.py in <cell line: 0>()
#       2   print(fname + " Akter "+ lname)
#       3
# ----> 4 get_greeting("Aeysha")
#
# TypeError: get_greeting() missing 1 required positional argument: 'lname'

# %%
def get_greeting(name = "FriendName"):
  print("Hello " , name)

get_greeting("Aeysha ")
# Out:
# Hello  Aeysha

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(name = "Buddy", animal = "dog")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("Buddy","dog")
# Out:
# I have a Buddy
# My Buddy's name is dog

# %%
def my_function(animal, name, age):
  print("I have a",age," years old", animal)

my_function("Buddy","dog", 5)
# Out:
# I have a 5  years old Buddy

# %%
def my_function(animals):
  for animal in animals:
    print(animal)

my_animals = ["dog", "cat", "cow", "Tiger"]
my_function(my_animals)
# Out:
# dog
# cat
# cow
# Tiger

# %%
def my_function(human):
  print("Name: ", human["name"])
  print("Age: ", human["age"])

my_human = {"name" : "Aeysha", "age" : 22}
my_function(my_human)
# Out:
# Name:  Aeysha
# Age:  22

# %%
def my_function(x,y):
  return x+y

result = my_function(10,20)
print(result)
# Out:
# 30

# %%
def my_function():
  return ["apple", "banana", "cherry"]

fruits = my_function()
print(fruits[0])
print(fruits[1])
print(fruits[2])
# Out:
# apple
# banana
# cherry

# %%
def my_function():
  return (10, 20)

x, y = my_function()
print("x:", x)
print("y:", y)
# Out:
# x: 10
# y: 20

# %%
def my_function(name, /):
  print("Hello", name)

my_function("Purnia")
# Out:
# Hello Purnia

# %%
def my_function(*, name):
  print("Hello", name)

my_function(name = "Purnia")
# Out:
# Hello Purnia

# %%
def my_function(*kids):
  print("The youngers child is " + kids[2])

my_function("Purnia", "Aeysha", "Farjana")
# Out:
# The youngers child is Farjana

# %%
def my_function(*args):
  print("Type:", type(args))
  print("First argument:", args[0])
  print("Second argument:", args[1])
  print("All argument:", args)

my_function("Purnia", "Aeysha", "Farjana")
# Out:
# Type: <class 'tuple'>
# First argument: Purnia
# Second argument: Aeysha
# All argument: ('Purnia', 'Aeysha', 'Farjana')

# %%
def my_function(greeting, *names):
  for name in names:
    print(greeting, name)

my_function("Hello", "Purnia", "Aeysha", "Farjana")
# Out:
# Hello Purnia
# Hello Aeysha
# Hello Farjana

# %%
def my_function(*numbers):
  total = 0
  for num in numbers:
    total += num
  return total

print(my_function(1, 2, 3))
print(my_function(10, 20, 30,40))
print(my_function(2))
# Out:
# 6
# 100
# 2

# %%
def my_function(*numbers):
  if len(numbers) == 0:
    return None
  max_num = numbers[0]
  for num in numbers:
    if num > max_num:
      max_num = num
  return max_num
print(my_function(3, 7, 2, 9, 1))
# Out:
# 9

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])
my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %%
def my_function(**myvar):
  print("Type:", type(myvar))
  print("Name:", myvar["name"])
  print("Age:", myvar["age"])
  print("All data:", myvar)
my_function(name = "Tobias", age = 30, city = "Bergen")
# Out:
# Type: <class 'dict'>
# Name: Tobias
# Age: 30
# All data: {'name': 'Tobias', 'age': 30, 'city': 'Bergen'}

# %%
def my_function(username, **details):
  print("Username:", username)
  print("Additional details:")
  for key, value in details.items():
    print(" ", key + ":", value)

my_function("emil123", age = 25, city = "Oslo", hobby = "coding")
# Out:
# Username: emil123
# Additional details:
#   age: 25
#   city: Oslo
#   hobby: coding

# %%
def my_function(title, *args, **kwargs):
  print("Title:", title)
  print("Positional arguments:", args)
  print("Keyword arguments:", kwargs)
my_function("User Info", "Emil", "Tobias", age = 25, city = "Oslo")
# Out:
# Title: User Info
# Positional arguments: ('Emil', 'Tobias')
# Keyword arguments: {'age': 25, 'city': 'Oslo'}

# %%
def my_function(a, b, c):
  return a + b + c
numbers = [1, 2, 3]
result = my_function(*numbers)
print(result)
# Out:
# 6

# %%
def my_function(fname, lname):
  print("Hello", fname, lname)

person = {"fname": "Emil", "lname": "Refsnes"}
my_function(**person)
# Out:
# Hello Emil Refsnes

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
# Out:
# 300

# %%
def myfunc():
  x = 300
  print(x)

myfunc()
# Out:
# 300

# %%
x = 300

def myfunc():
  print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %%
x = 300

def myfunc():
  x = 200
  print(x)

myfunc()

print(x)
# Out:
# 200
# 300

# %%
def myfunc():
  global x
  x = 300

myfunc()

print(x)
# Out:
# 300

# %%
x = 300

def myfunc():
  global x
  x = 200

myfunc()

print(x)
# Out:
# 200

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x
print(myfunc1())
# Out:
# hello

# %%
x = "global"

def outer():
  x = "enclosing"
  def inner():
    x = "local"
    print("Inner:", x)
  inner()
  print("Outer:", x)

outer()
print("Global:", x)
# Out:
# Inner: local
# Outer: enclosing
# Global: global

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner
@changecase
def myfunction():
  return "Hello Sally"
print(myfunction())
# Out:
# HELLO SALLY

# %%
def changecase(func):
  def myinner():
    return func().upper()
  return myinner
