# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func():
  print("Hello!, Function")
func()
func()
# Out:
# Hello!, Function
# Hello!, Function

# %%
samp1 = 77
cal1 = (samp1 - 32) * 5 / 9
print(cal1)

samp2 = 90
cal2 = (samp2 - 32) * 5 / 9
print(cal2)

cal3 = cal2 - cal1
print(cal3)
# Out:
# 25.0
# 32.22222222222222
# 7.222222222222221

# %%
def farenheit_to_cal(farenheit):
  return (farenheit - 32) * 5 / 9
print(farenheit_to_cal(90))
print(farenheit_to_cal(20))
print(farenheit_to_cal(46))
# Out:
# 32.22222222222222
# -6.666666666666667
# 7.777777777777778

# %%
def get_greeting():
  return "Hello!!, From a function"

message = get_greeting()
print(message)
print(get_greeting())
# Out:
# Hello!!, From a function
# Hello!!, From a function

# %%
def get_greeting():
  pass

# %%
def get_greeting(fname):
  print(fname + "Purnia")

get_greeting("Aeysha ")
get_greeting("Akter ")
# Out:
# Aeysha Purnia
# Akter Purnia

# %%
def get_greeting(fname):
  print(fname , "Purnia")

get_greeting("Aeysha ")
# Out:
# Aeysha  Purnia

# %%
def get_greeting(fname, lname):
  print(fname + " Akter "+ lname)

get_greeting("Aeysha", "Purnia")
# Out:
# Aeysha Akter Purnia

# %%
def get_greeting(fname, lname):
  print(fname + " Akter "+ lname)

get_greeting("Aeysha")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2300808540.py in <cell line: 0>()
#       2   print(fname + " Akter "+ lname)
#       3
# ----> 4 get_greeting("Aeysha")
#
# TypeError: get_greeting() missing 1 required positional argument: 'lname'

# %%
def get_greeting(name = "FriendName"):
  print("Hello " , name)

get_greeting("Aeysha ")
# Out:
# Hello  Aeysha

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(name = "Buddy", animal = "dog")
# Out:
# I have a dog
# My dog's name is Buddy
