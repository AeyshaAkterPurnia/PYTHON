# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(list(range(5)))
print(list(range(4)))
print(range(3))
# Out:
# [0, 1, 2, 3, 4]
# [0, 1, 2, 3]
# range(0, 3)

# %%
r = range(10)
print(r[2])
print(r[:3])
# Out:
# 2
# range(0, 3)
