# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Dates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime

x = datetime.datetime.now()
print(x)
print(x.year)
print(x.strftime("%A"))
# Out:
# 2026-02-05 14:31:38.894064
# 2026
# Thursday

# %%
import datetime
x = datetime.datetime(2020, 5, 17)
print(x)
# Out:
# 2020-05-17 00:00:00

# %%
import datetime
x = datetime.datetime(2018, 6, 1)
print(x.strftime("%B"))
print(x.strftime("%A"))
# Out:
# June
# Friday
