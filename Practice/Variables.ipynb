# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 6.7
y = "Purnia"
print(x)
print(y)
# Out:
# 6.7
# Purnia

# %%
a = 9
a = "Purnia"
print(a) # last value will be printed
# Out:
# Purnia

# %%
x = 6.7
y = "Purnia"
print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'str'>

# %%
x, y, z = "Aeysha", 'Purnia', 'Farjana'
print(x)
print(y)
print(z)
# Out:
# Aeysha
# Purnia
# Farjana

# %%
x = "Purnia"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Purnia is awesome

# %%
a = 3.5
b = 2
print(a+b)
# Out:
# 5.5

# %%
a = "Purnia"
b = 2
print(a,b)
# Out:
# Purnia 2

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Purnia is " + x)

myfunc()

print("Purnia is " + x)
# Out:
# Purnia is fantastic
# Purnia is awesome
