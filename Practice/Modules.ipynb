# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Practice/Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greeting(name):
  print("Hello, " + name)
