# %% [markdown]
# <a href="https://colab.research.google.com/github/AeyshaAkterPurnia/PYTHON/blob/main/Prictice/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
p = "American International University Bangladesh"
print(len(p))
# Out:
# 44

# %%
message = "Bangladesh is a beutiful country"
print("country" in message)
# Out:
# True

# %%
message = "Bangladesh is a beutiful country"
if "country" in message:
 print("Yes, 'country' is present.")
# Out:
# Yes, 'country' is present.

# %%
a = " What's up, Purnia  "
age = 24
b = f"{a}{age}"
print(a.upper())
print(a.lower())
print(a.strip())
print(a.split(","))
print(b)
# Out:
#  WHAT'S UP, PURNIA
#  what's up, purnia
# What's up, Purnia
# [" What's up", ' Purnia  ']
#  What's up, Purnia  24
